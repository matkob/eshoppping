# %%
import pandas as pd
import numpy as np
import calendar

# %% [markdown]
# # Data reorganization

# %%
data = pd.read_pickle('data/merged.pickle')
data.columns
# Out:
# Index(['session_id', 'time', 'user_id', 'product_id', 'event', 'discount',
#        'purchase_id', 'made_purchase', 'known_product', 'product', 'price',
#        'cat_0', 'cat_1', 'cat_2', 'cat_3', 'city', 'street', 'name_1',
#        'name_2', 'surname', 'female', 'purchase_time', 'delivery_time',
#        'delivery_company', 'delivery_duration', 'duration',
#        'syntetic_duration', 'agg_time_spent', 'weekday', 'hour', 'weekday_sin',
#        'weekday_cos', 'hour_sin', 'hour_cos', 'ends_with_purchase'],
#       dtype='object')

# %%
data.head()
# Out:
#    session_id                time  user_id  product_id         event  \
# 0    100001.0 2020-01-17 16:08:57    102.0      1001.0  view_product
# 1    100002.0 2020-01-07 05:10:41    102.0      1277.0  view_product
# 2    100002.0 2020-01-07 05:14:26    102.0      1276.0  view_product
# 3    100003.0 2020-01-16 09:37:42    102.0      1276.0  view_product
# 4    100003.0 2020-01-16 09:38:22    102.0      1277.0  view_product
#
#    discount  purchase_id  made_purchase  known_product  \
# 0         0          NaN          False           True
# 1        20          NaN          False           True
# 2        20          NaN          False           True
# 3         0          NaN          False           True
# 4         0          NaN          False           True
#
#                          product  ...        duration syntetic_duration  \
# 0  telefon siemens gigaset da310  ... 00:02:43.251191              True
# 1        apple ipad mini 64gb 4g  ...        00:03:45             False
# 2           apple ipad mini 64gb  ... 00:02:43.251191              True
# 3           apple ipad mini 64gb  ...        00:00:40             False
# 4        apple ipad mini 64gb 4g  ... 00:02:43.251191              True
#
#    agg_time_spent weekday hour weekday_sin weekday_cos  hour_sin  hour_cos  \
# 0 00:08:06.502383       4   16   -0.433884   -0.900969 -0.866025 -0.500000
# 1 00:05:23.251191       1    5    0.781831    0.623490  0.965926  0.258819
# 2        00:03:45       1    5    0.781831    0.623490  0.965926  0.258819
# 3 00:06:28.251191       3    9    0.433884   -0.900969  0.707107 -0.707107
# 4 00:09:08.251191       3    9    0.433884   -0.900969  0.707107 -0.707107
#
#   ends_with_purchase
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
#
# [5 rows x 35 columns]

# %% [markdown]
# # Distribution analysis

# %% [markdown]
# ## Time

# %% [markdown]
# ### Daily activity

# %%
data.time.apply(lambda t: t.replace(hour=0, minute=0, second=0)).hist(xrot=60)

# %% [markdown]
# ### Daily purchases

# %%
data[data.made_purchase].time.apply(lambda t: t.replace(hour=0, minute=0, second=0)).hist(xrot=60)

# %% [markdown]
# ### Hourly activity

# %%
data.time.apply(lambda t: t.hour).hist(bins=24)

# %% [markdown]
# ### Hourly purchases

# %%
data[data.made_purchase].time.apply(lambda t: t.hour).hist(bins=24)

# %% [markdown]
# ### Weekday activity (starting from Monday)

# %%
data.time.apply(lambda t: t.weekday()).hist(xrot=60, bins=7)

# %% [markdown]
# ### Weekday purchases (starting from Monday)

# %%
data[data.made_purchase].time.apply(lambda t: t.weekday()).hist(xrot=60, bins=7)

# %% [markdown]
# # Event

# %% [markdown]
# ## Type

# %%
data.event.hist()

# %%
data.event.value_counts()
# Out:
# view_product    27839
# buy_product      3184
# Name: event, dtype: int64

# %% [markdown]
# ## Completed duration

# %%
data.duration.apply(lambda t: t.total_seconds()).hist()

# %% [markdown]
# ## Raw duration

# %%
data[~data.syntetic_duration].duration.apply(lambda t: t.total_seconds()).hist()

# %% [markdown]
# ## Completed buy event duration

# %%
data[data.made_purchase].duration.apply(lambda t: t.total_seconds()).hist()

# %% [markdown]
# ## Raw buy event duration

# %%
data[data.made_purchase & ~data.syntetic_duration].duration.apply(lambda t: t.total_seconds()).hist()

# %% [markdown]
# ## Aggregated time spent before buy event

# %%
data[data.made_purchase].agg_time_spent.apply(lambda t: t.total_seconds()).hist()

# %% [markdown]
# ## Aggregated time spent before any event

# %%
data.agg_time_spent.apply(lambda t: t.total_seconds()).hist()

# %% [markdown]
# # Product

# %% [markdown]
# ## Main category of purchased products

# %%
data[data.made_purchase].cat_0.hist(xrot=60)

# %% [markdown]
# ## Secondary categories of purchased products

# %%
data[data.made_purchase].cat_1.hist(xrot=60)

# %%
data[data.made_purchase].cat_2.hist(xrot=60)

# %%
data[data.made_purchase].cat_3.hist(xrot=60)

# %% [markdown]
# ## Price

# %% [markdown]
# ### Purchased products

# %%
data[data.made_purchase].price.hist()

# %% [markdown]
# ### All products

# %%
data.price.hist()

# %% [markdown]
# # User

# %% [markdown]
# ## Male or female

# %%
data.female.apply(lambda is_female: 'FEMALE' if is_female else 'MALE').hist()

# %% [markdown]
# ## City

# %%
data.city.hist(xrot=60)

# %%
data.city.value_counts()
# Out:
# kutno       4034
# radom       3918
# mielec      3820
# konin       3808
# police      3588
# warszawa    3479
# szczecin    3439
# gdynia      3408
# Name: city, dtype: int64
